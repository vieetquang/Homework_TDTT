# %% [markdown]
# # W8A1

# %%
try:
    a, b = map(int, input().split())
    print(f"{a / b:.2f}")
except ZeroDivisionError:
    print("Loi chia khong")
# Out:
# Loi chia khong

# %% [markdown]
# # W8A2

# %%
try:
    my_list = list(map(int, input().split()))
    n = int(input())
    print(my_list[n])
except IndexError:
    print("Truy cap chi so sai")
# Out:
# Truy cap chi so sai

# %% [markdown]
# # W8A3

# %%
try:
    a = input()
    b = set()
    s = 0
    while s !=1 and s not in b:
        b.add(s)
        s = 0
        for i in str(a):
            s += int(i)**2
        a = s
    if s == 1:
        print("Yes")
    else:
        print("No")
except ValueError:
    print("lỗi nè")
# Out:
# Yes

# %% [markdown]
# # W8A4

# %%
try:
    a, b = map(int, input().split())
except ValueError:
    print("Nhap sai kieu du lieu")
else:
    print(a + b)
finally:
    print("Ket thuc chuong trinh.")
# Out:
# Nhap sai kieu du lieu
# Ket thuc chuong trinh.

# %% [markdown]
# # W8A5

# %%
lst = input().split()
result = []

for x in lst:
    try:
        result.append(int(x))
    except ValueError:
        print(f"Khong the chuyen {x}")

print(result)
# Out:
# Khong the chuyen A
# [1, 5, 6, 4]

# %% [markdown]
# # W8A6

# %%
import math
try:
    x = float(input())
    if x < 0:
        raise ValueError
    print(f"{math.sqrt(x):.2f}")
except ValueError:
    print("So am")
# Out:
# So am

# %% [markdown]
# # W8A7

# %%
try:
    age = int(input())
    if age < 0:
        raise ValueError
    print(2025 - age)
except:
    print("Tuoi khong hop le")
# Out:
# Tuoi khong hop le

# %% [markdown]
# # W8A8

# %%
filename = input().strip().lower()

if filename.endswith(".txt") or filename.endswith(".zip"):
    print("Doc file thanh cong")
else:
    print("File khong hop le")
# Out:
# Doc file thanh cong

# %% [markdown]
# # W8A9

# %%
s = input().strip()
try:
    if '.' in s:
        raise ValueError
    print(int(s))
except ValueError:
    print("Chuoi khong hop le")
# Out:
# Chuoi khong hop le

# %% [markdown]
# # W8A10

# %%
data = list(map(int, input().split()))
n = data[0]
arr = data[1:]
if n > 0 and len(arr) == n and len(set(arr)) == n:
    print(sum(arr))
else:
    print("Mang khong hop le")
# Out:
# 15

# %% [markdown]
# # W8A11

# %%
import re
for _ in range(int(input())):
    try:
        re.compile(input())
        print("True")
    except re.error:
        print("False")
# Out:
# True
# True
