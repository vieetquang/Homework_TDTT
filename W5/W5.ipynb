# %% [markdown]
# # W4A1

# %%
n = int(input())
tong = 0
if n <= 1000:
    for so in range(n + 1):
        tong += so
    print(tong)
else:
    print("So phai <= 1000")

# %% [markdown]
# # W4A2

# %%
n = int(input())
def songuyento(a):
    if a < 2:
        return False
    else:
        i = 2
        while i ** 2 <= a:
            if a % i == 0:
                return False
            i += 1
        return True
songuyento(n)

# %% [markdown]
# # W4A3

# %%
n = int(input())
def giaithua(a):
    tich = 1
    if 0 < a < 100: 
        for i in range(1, a + 1):
            tich *= i
        return tich
    else:
        return False
giaithua(n)

# %% [markdown]
# # W4A4

# %%
n = int(input())
def demchuso(a):
    sochuso = 0
    if a == 0:
        return 1
    a = abs(a)
    while a % 10 >= 1:
        a //= 10
        sochuso += 1
    return sochuso
demchuso(n)

# %% [markdown]
# # W4A5

# %%
n = int(input())
lst = input()
lst = list(map(int, lst.split()))
if len(lst) == n: 
    for i in lst:
        if i == 42:
            print("I've found the meaning of life")
            break
        else:
            print("It's a joke")
            break
else:
    print("Lỗi")

# %% [markdown]
# # W4A6

# %%
a = int(input())
b = int(input())
tong = 0 
for i in range(a, b + 1):
    if songuyento(i) == True:
        tong += i
print(tong)

# %% [markdown]
# # W4A7

# %%
n = int(input())
uoc = []
if n < 2:
    print("Lỗi")
else:
    for i in range(1, n+1):
        if n % i == 0 and songuyento(i) == True:
                uoc.append(i)
    
max(uoc)

# %% [markdown]
# # W4A8

# %%
def daoso(a):
    chuoi=str(a)
    a=int(chuoi[::-1])
    return a
x = int(input())
sobuoc = 0
while x != daoso(x):
    x = x + daoso(x)
    sobuoc+=1
print(sobuoc, x)
# Out:
# 2 12221

# %% [markdown]
# # W4A9

# %%
n = int(input())
k = 1
while k**2 <= n:
    print(k**2, end=' ')
    k += 1
# Out:
# 1 4 9 16 25 36 49

# %% [markdown]
# # W4A10

# %%
n = int(input())
def collatz(a):
    buoc = 1
    while a != 1:
        if a % 2 == 0: 
            a //= 2
        else:
            a = a*3+1
        buoc += 1
    return buoc
buocto = 0 
sobe = 0
for i in range(1, n+1):
    step = collatz(i)
    if step > buocto:
        buocto = step
        sobe = i
print(sobe, buocto)
# Out:
# 54 113

# %% [markdown]
# # W4A11

# %%
n = int(input())
so_uoc_chan = 0
for i in range(1, n+1):
    if n % i == 0 and i % 2 == 0:
        so_uoc_chan += 1
print(so_uoc_chan)

# %% [markdown]
# # W4A12

# %%
tiengui = int(input())
sothang =int(input())
for i in range(sothang +1):
    tongtien = tiengui
    tiengui *= 1.007
print(int(tongtien))

# %% [markdown]
# # W4A13

# %%
so_a = int(input())
so_b = int(input())
tong_uoc_a = 0
tong_uoc_b = 0
for i in range(1, so_a):
    if so_a % i == 0:   
        tong_uoc_a += i
for i in range(1, so_b):
    if so_b % i == 0:   
        tong_uoc_b += i
if tong_uoc_a == so_b and tong_uoc_b == so_a:
    print("True")
else:
    print("False")

# %% [markdown]
# # W4A14

# %%
m = int(input())
n = int(input())
uoc = []
for i in range(1, min(m,n)):
    if m % i == 0 and n % i == 0:
        uoc.append(i)
print(max(uoc))

# %% [markdown]
# # W4A15

# %%
tong_con = int(input())
tong_chan = int(input())
valid = False
for so_ga in range(tong_con +1):
    so_cho = tong_con - so_ga
    if so_ga*2 +so_cho*4 == tong_chan:
        print(so_ga, so_cho)
        valid = True
if valid == False:
    print("invalid")

# %% [markdown]
# # W4A16

# %%
for i in range(100):
    if i % 3 == 0 and i % 2 == 0:
        print(i)

# %% [markdown]
# # W4A17

# %%
n = int(input())
for i in range(1, 11):
    print(f"{n} * {i} = {n*i}")

# %% [markdown]
# # W4A18

# %%
a = int(input())
b = int(input())
for i in range(1, min(a,b)):
    if a % i == 0 and b % i == 0:
        print(i)

# %% [markdown]
# # W4A19

# %%
for i in range(1, 1001):
    if i % 2 == 0:
        print(i)

# %% [markdown]
# # W4A20

# %%
n = int(input())
x = False
while n != 1:
    n //= 2
    if n % 2 != 0 and n !=1:
        break
    else:
        x == True
if x == True:
    print("Yes")
else:
    print("NO")

# %% [markdown]
# # W4A21

# %%
n = input()
tong = 0
for i in n:
    tong += int(i)
print(tong)

# %% [markdown]
# # W4A22

# %%
n = input()
even = 0
odd = 0
for i in n:
    if int(i) % 2 == 0:
        even += 1
    else:
        odd += 1
print(f"even:{even}, odd:{odd}")

# %% [markdown]
# # W4A23

# %%
n = int(input())
tong = 0
for i in range(1, n+1):
    tong += i
    if tong > n:
        print(i-1)
        break

# %% [markdown]
# # W4A24

# %%
A = int(input())
tong = 0
if A >= 6:
    print("lỗi")
for i in range(1,100):
    tong += 1/i
    if tong > A:
        print(i-1)
        break

# %% [markdown]
# # W4A25

# %%
lst = []
n = 0
while n != -1:
    n = int(input())
    if n != -1:
        lst.append(n)
print(f"so lon nhat: {max(lst)}, so nho nhat {min(lst)}")

# %% [markdown]
# # W4A26

# %%
n = int(input())
def min_fib(a):
 sohang1 = 1
 sohang2 = 1
 for i in range(a +1):
    sothu1, sothu2 = sothu2, sothu1+sothu2
    if sothu3 > a:
        return sohang1
    
print(min_fib(n))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 10
#       7     if sothu3 > a:
#       8         return sohang1
# ---> 10 print(min_fib(n))
#
# Cell In[8], line 6, in min_fib(a)
#       4 sohang2 = 1
#       5 for i in range(a +1):
# ----> 6    sothu1, sothu2 = sothu2, sothu1+sothu2
#       7    if sothu3 > a:
#       8        return sohang1
#
# UnboundLocalError: cannot access local variable 'sothu2' where it is not associated with a value

# %% [markdown]
# # W4A27

# %%
n = input()
def dem_tu(a):
    so_tu = 0
    chi_so = 0
    space_truoc = True
    try:
        while True:
            if a[chi_so] !=" ":
                if space_truoc:
                    so_tu += 1
                    space_truoc = False
            else: 
                space_truoc = True
            chi_so += 1
    except IndexError:
        pass
    return so_tu

print(dem_tu(n))

# %% [markdown]
# # W4A28

# %%
n = input()
vao_tu = False
tu_dau = ""
for i in range(len(n)):
    if n[i] != " ":
        vao_tu = True
        tu_dau += n[i]
    elif n[i] == " " and not vao_tu:
        continue
    elif n[i] == " " and vao_tu:
        break

print(tu_dau)
# Out:
# a

# %% [markdown]
# # W4A29

# %%
n = input()
strs = n.split(',')
tong = 0
for i in strs:
    a = i.strip()
    so = int(a)
    tong += so
print(tong)

# %% [markdown]
# # W4A30

# %%
n = input()
in_hoa = 0
in_thuong = 0
num = 0 
for i in n:
   try: 
    if i.isupper():
        in_hoa += 1
    elif i.islower():
        in_thuong += 1
    elif i.isdigit():
        num += 1
   except ValueError:
        continue
print(f"in hoa :{in_hoa}, in thường: {in_thuong}, số: {num}")

# %% [markdown]
# # W4A31

# %%
n = input()
tong = 0
for i in n:
    if i.isdigit():
        tong += int(i)
print(tong)

# %% [markdown]
# # W4A32

# %%
n = input()
in_hoa = 0
in_thuong = 0
ki_tudb = 0
num = 0
for i in n:
    if i.isupper():
        in_hoa += 1
    elif i.islower():
        in_thuong += 1
    elif i.isdigit():
        num += 1
    else:
        ki_tudb += 1
if in_hoa >= 1 and in_thuong >= 1 and ki_tudb >= 1 and num >=1 and len(n)>= 6:
    print("Mật khẩu mạnh")
else:
    print("Mật khẩu yếu")

# %% [markdown]
# # W4A33

# %%
n = int(input())
b = " "
chi_so = 0
while n > 0:
    so = n % 10
    if chi_so % 3 == 0 and n != 0 and chi_so != 0:
        b = "." + b
    b = str(so) + b
    n = n // 10
    chi_so += 1
print(b)

# %% [markdown]
# # W4A34

# %%
a = input()
b = input()
while True:
    start = a.find(b)
    if start == -1:
        break
    end = start + len(b)
    phantruoc = a[:start]
    phansau = a[end:]
    a = phantruoc + phansau
print(a)
